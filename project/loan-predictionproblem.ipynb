# %% [markdown]
# -----------------------------------------------CLASSIFICATION PROBLEM---------------------------------------------

# %% [markdown]
# This is a binary classification problem where we need to predict whether or not to approve a loan based on the past information of the person.

# %% [markdown]
# Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading dataset

# %%
data=pd.read_csv('../input/loan-prediction-problem-dataset/train_u6lujuX_CVtuZ9i.csv')

# %%
df=pd.read_csv('../input/loan-prediction-problem-dataset/train_u6lujuX_CVtuZ9i.csv')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#info about the Dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#Shape of the dataset
data.shape
# Out:
# (614, 13)

# %% [markdown]
# There are 614 rows and 13 columns in the Dataset.

# %%
#Description about the Dataset
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Here we can observe that the maximum value of ApplicantIncome and CoapplicantIncome is much higher than the 75%of the data of ApplicantIncome and CoapplicantIncome respectively.

# %%
#Datatypes of the features
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# Continous variables are:  CoapplicantIncome, ApplicantIncome,  LoanAmount,  Loan_Amount_Term,  Credit_History.
# Categorical Variables are:   Loan_ID, Gender,  Married,  Dependents,  Eduaction,  Self_Employed,  Property_area,  Loan_Status.

# %%
#Checking for missing values
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are missing values in the following features:-             'Gender', 'Married', 'Dependents', 'Self_Employed', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History'.

# %% [markdown]
# There are 22 missing values in the LoanAmount variable so we fill the missing values by the mean of all values in that variable.

# %%
data['LoanAmount']=data['LoanAmount'].fillna(data['LoanAmount'].mean())

# %% [markdown]
# There are 50 missing values in the credit History. we fill those missing values by the median of Credit History.

# %%
data['Credit_History']=data['Credit_History'].fillna(data['Credit_History'].median())

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# We drop all other missing values in the variables.

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (480, 13)

# %% [markdown]
# Now,the new shape of the dataset is (542,13).

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
df['Gender'].value_counts()
# Out:
# Male      394
# Female     86
# Name: Gender, dtype: int64

# %% [markdown]
# Out of 542, there are 444 males and 98 females applying for loan.

# %%
df['Married'].value_counts()
# Out:
# Yes    311
# No     169
# Name: Married, dtype: int64

# %% [markdown]
# We observe there are more number of married people applying for loan than unmarried.

# %%
df['Education'].value_counts()
# Out:
# Graduate        383
# Not Graduate     97
# Name: Education, dtype: int64

# %% [markdown]
# More than half of the total applying for loan are graduates.

# %%
df['Self_Employed'].value_counts()
# Out:
# No     414
# Yes     66
# Name: Self_Employed, dtype: int64

# %% [markdown]
# People who are self employed tend not to apply for loan.

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    191
# Urban        150
# Rural        139
# Name: Property_Area, dtype: int64

# %% [markdown]
# There is no much difference among the locality of people applying for loan. Almost people from all areas apply for a loan.

# %%
plt.boxplot(df['ApplicantIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80fdc0c048>,
#   <matplotlib.lines.Line2D at 0x7f80fdc0c3c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80fdc0c748>,
#   <matplotlib.lines.Line2D at 0x7f80fdc0cac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80fdc77cf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80fdc0ce48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80fdc17208>],
#  'means': []}

# %%
plt.boxplot(df['CoapplicantIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80fdb93c50>,
#   <matplotlib.lines.Line2D at 0x7f80fdb93fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80fdba2390>,
#   <matplotlib.lines.Line2D at 0x7f80fdba26d8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80fdb93940>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80fdba2a58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80fdba2dd8>],
#  'means': []}

# %%
plt.boxplot(df['LoanAmount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80fdb0e128>,
#   <matplotlib.lines.Line2D at 0x7f80fdb0e4a8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80fdb0e828>,
#   <matplotlib.lines.Line2D at 0x7f80fdb0eba8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80fdb7fdd8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80fdb0ef28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80fdb192e8>],
#  'means': []}

# %%
plt.boxplot(df['Loan_Amount_Term'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80fdaebe80>,
#   <matplotlib.lines.Line2D at 0x7f80fdaf8240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80fdaf85c0>,
#   <matplotlib.lines.Line2D at 0x7f80fdaf8940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80fdaebb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80fdaf8cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80fda83080>],
#  'means': []}

# %%
plt.boxplot(df['Credit_History'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f80fda4de80>,
#   <matplotlib.lines.Line2D at 0x7f80fda58240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f80fda58550>,
#   <matplotlib.lines.Line2D at 0x7f80fda588d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f80fda4db70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f80fda58c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f80fda58fd0>],
#  'means': []}

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
sns.scatterplot(x='Property_Area',y='Loan_Status',data=df)

# %%
sns.scatterplot(x='Self_Employed',y='Loan_Status',data=df)

# %%
print(pd.crosstab(df['Property_Area'],df['Loan_Status']))
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          54   85
# Semiurban      42  149
# Urban          52   98

# %%
sns.countplot(df['Property_Area'],hue=df['Loan_Status'])

# %% [markdown]
# Out of all semiurban people who apply for a loan more than half of them got a loan.
# So this seems to a useful feature.

# %%
print(pd.crosstab(df['Gender'],df['Loan_Status']))
# Out:
# Loan_Status    N    Y
# Gender
# Female        32   54
# Male         116  278

# %%
sns.countplot(df['Gender'],hue=df['Loan_Status'])

# %% [markdown]
# Males have high chances of getting a loan.

# %%
print(pd.crosstab(df['Married'],df['Loan_Status']))
# Out:
# Loan_Status   N    Y
# Married
# No           64  105
# Yes          84  227

# %%
sns.countplot(df['Married'],hue=df['Loan_Status'])

# %% [markdown]
# Out of all married people who applied for a loan,maximum of them get their loan approved.

# %%
print(pd.crosstab(df['Self_Employed'],df['Loan_Status']))
# Out:
# Loan_Status      N    Y
# Self_Employed
# No             125  289
# Yes             23   43

# %%
sns.countplot(df['Self_Employed'],hue=df['Loan_Status'])

# %%
print(pd.crosstab(df['Education'],df['Loan_Status']))
# Out:
# Loan_Status     N    Y
# Education
# Graduate      112  271
# Not Graduate   36   61

# %%
sns.countplot(df['Education'],hue=df['Loan_Status'])

# %% [markdown]
# Half of the graduates who applied for loan got their loan approved.

# %% [markdown]
# Converting dependent categorical variable to continous variable.

# %%
df['Loan_Status'].replace('N',0,inplace=True)
df['Loan_Status'].replace('Y',1,inplace=True)

# %%
plt.title('Correlation Matrix')
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# As we can observe from the above correlation matrix that the dependent variable loan_status is dependent only on Credit_History.
# So we keep this independent variable and discard all other variables which are not related with the loan_status.

# %%
df2=df.drop(labels=['ApplicantIncome'],axis=1)

# %%
df2=df2.drop(labels=['CoapplicantIncome'],axis=1)

# %%
df2=df2.drop(labels=['LoanAmount'],axis=1)

# %%
df2=df2.drop(labels=['Loan_Amount_Term'],axis=1)

# %%
df2=df2.drop(labels=['Loan_ID'],axis=1)

# %%
df2.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
# 5   Male     Yes          2      Graduate           Yes             1.0
#
#   Property_Area  Loan_Status
# 1         Rural            0
# 2         Urban            1
# 3         Urban            1
# 4         Urban            1
# 5         Urban            1

# %% [markdown]
# Changing categorical variables to continous variables.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
le=LabelEncoder()
ohe=OneHotEncoder()

# %%
df2['Property_Area']=le.fit_transform(df2['Property_Area'])

# %%
df2['Dependents']=le.fit_transform(df2['Dependents'])

# %%
df2=pd.get_dummies(df2)

# %%
df2.dtypes
# Out:
# Dependents                  int64
# Credit_History            float64
# Property_Area               int64
# Loan_Status                 int64
# Gender_Female               uint8
# Gender_Male                 uint8
# Married_No                  uint8
# Married_Yes                 uint8
# Education_Graduate          uint8
# Education_Not Graduate      uint8
# Self_Employed_No            uint8
# Self_Employed_Yes           uint8
# dtype: object

# %% [markdown]
# Now we can see each and every variable is changed to continous variable.

# %%
df2=df2.drop(labels=['Gender_Female'],axis=1)

# %%
df2=df2.drop(labels=['Married_No'],axis=1)

# %%
df2=df2.drop(labels=['Education_Not Graduate'],axis=1)

# %%
df2=df2.drop(labels=['Self_Employed_No'],axis=1)

# %%
df2.head()
# Out:
#    Dependents  Credit_History  Property_Area  Loan_Status  Gender_Male  \
# 1           1             1.0              0            0            1
# 2           0             1.0              2            1            1
# 3           0             1.0              2            1            1
# 4           0             1.0              2            1            1
# 5           2             1.0              2            1            1
#
#    Married_Yes  Education_Graduate  Self_Employed_Yes
# 1            1                   1                  0
# 2            1                   1                  1
# 3            1                   0                  0
# 4            0                   1                  0
# 5            1                   1                  1

# %%
plt.title('Correlation Matrix')
sns.heatmap(df2.corr(),annot=True)

# %% [markdown]
# Loan status is least correlated with self_employed_yes,education_graduate,dependents.

# %%
df2=df2.drop('Self_Employed_Yes',1)

# %%
df2=df2.drop('Dependents',1)

# %%
df2=df2.drop('Education_Graduate',1)

# %%
X=df2.drop('Loan_Status',1)

# %%
Y=df2['Loan_Status']

# %% [markdown]
# Splitting train and test dataset.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=6)

# %%
print('Shape of X_train is: ',x_train.shape)
print('Shape of X_test is: ',x_test.shape)
print('Shape of Y_train is: ',y_train.shape)
print('Shape of y_test is: ',y_test.shape)
# Out:
# Shape of X_train is:  (384, 4)
# Shape of X_test is:  (96, 4)
# Shape of Y_train is:  (384,)
# Shape of y_test is:  (96,)

# %% [markdown]
# ---**LOGISTIC REGRESSION**---

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()

# %%
log.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log.score(x_train,y_train)
# Out:
# 0.8020833333333334

# %%
#Predicting trest dataset
pred=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8333333333333334

# %% [markdown]
# This seems to be a good accuracy score.

# %%
from sklearn import metrics

# %% [markdown]
# Confusion matrix

# %%
metrics.confusion_matrix(y_test,pred)
# Out:
# array([[12, 14],
#        [ 2, 68]])

# %% [markdown]
# From confusion matrix we can observe that
#
# * True positive value= 23
# * True negative value=1
# * False negative=16
# * False positive=69

# %%
metrics.recall_score(y_test,pred)
# Out:
# 0.9714285714285714

# %%
metrics.precision_score(y_test,pred)
# Out:
# 0.8292682926829268

# %%
metrics.f1_score(y_test,pred)
# Out:
# 0.8947368421052632

# %%
data={'y_test':y_test,'pred':pred}
pd.DataFrame(data=data)
# Out:
#      y_test  pred
# 40        0     1
# 339       1     1
# 204       1     1
# 431       0     0
# 315       1     1
# ..      ...   ...
# 144       1     1
# 217       1     1
# 70        1     1
# 456       1     1
# 384       0     1
#
# [96 rows x 2 columns]

# %% [markdown]
# -----**DECISION TREE**------

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(x_train,y_train)
# Out:
# 0.8072916666666666

# %%
pred1=clf.predict(x_test)

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.78125

# %%
metrics.confusion_matrix(y_test,pred1)
# Out:
# array([[13, 13],
#        [ 8, 62]])

# %% [markdown]
# From confusion matrix we can observe that
# * True positive value= 23
# * True negative value=1
# * False negative=16
# * False positive=69

# %%
metrics.f1_score(y_test,pred1)
# Out:
# 0.8551724137931035

# %%
metrics.recall_score(y_test,pred1)
# Out:
# 0.8857142857142857

# %%
metrics.precision_score(y_test,pred1)
# Out:
# 0.8266666666666667
